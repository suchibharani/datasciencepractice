# %%
import pandas as pd

# %%
df_faa_dataset = pd.read_csv('/Users/suchitra/Desktop/work/private/course/data science new resource/Projects/ProjectswithSolution/Project2/Datasets/test.csv')

# %%
df_faa_dataset.shape
# Out:
# (418, 11)

# %%
df_faa_dataset.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_faa_dataset.columns
# Out:
# Index([u'PassengerId', u'Pclass', u'Name', u'Sex', u'Age', u'SibSp', u'Parch',
#        u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %%
df_analyze_dataset=df_faa_dataset[['PassengerId','Name','Pclass','Age']]

# %%
df_analyze_dataset
# Out:
#      PassengerId                                               Name  Pclass  \
# 0            892                                   Kelly, Mr. James       3
# 1            893                   Wilkes, Mrs. James (Ellen Needs)       3
# 2            894                          Myles, Mr. Thomas Francis       2
# 3            895                                   Wirz, Mr. Albert       3
# 4            896       Hirvonen, Mrs. Alexander (Helga E Lindqvist)       3
# 5            897                         Svensson, Mr. Johan Cervin       3
# 6            898                               Connolly, Miss. Kate       3
# 7            899                       Caldwell, Mr. Albert Francis       2
# 8            900          Abrahim, Mrs. Joseph (Sophie Halaut Easu)       3
# 9            901                            Davies, Mr. John Samuel       3
# 10           902                                   Ilieff, Mr. Ylio       3
# ...

# %%
type(df_analyze_dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
df_analyze_dataset['Age'].fillna(value='No',inplace=True)
# Out:
# /Users/suchitra/anaconda2/lib/python2.7/site-packages/pandas/core/generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_faa_dataset.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_analyze_dataset
# Out:
#      PassengerId                                               Name  Pclass  \
# 0            892                                   Kelly, Mr. James       3
# 1            893                   Wilkes, Mrs. James (Ellen Needs)       3
# 2            894                          Myles, Mr. Thomas Francis       2
# 3            895                                   Wirz, Mr. Albert       3
# 4            896       Hirvonen, Mrs. Alexander (Helga E Lindqvist)       3
# 5            897                         Svensson, Mr. Johan Cervin       3
# 6            898                               Connolly, Miss. Kate       3
# 7            899                       Caldwell, Mr. Albert Francis       2
# 8            900          Abrahim, Mrs. Joseph (Sophie Halaut Easu)       3
# 9            901                            Davies, Mr. John Samuel       3
# 10           902                                   Ilieff, Mr. Ylio       3
# ...

# %%
df_analyze_dataset.shape
# Out:
# (418, 4)

# %%
df_final_dataset = df_analyze_dataset.dropna(subset=['Age'])

# %%
df_final_dataset.shape
# Out:
# (418, 4)

# %%
df_final_Age = df_final_dataset.groupby('Pclass')

# %%
df_final_Age.size()
# Out:
# Pclass
# 1    107
# 2     93
# 3    218
# dtype: int64
